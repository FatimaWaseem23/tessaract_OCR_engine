# %%
import cv2
from PIL import Image
import pytesseract

# %%
#loading an image into memory to get its raw text
file_image="certificate.png"
img= Image.open(file_image)
print(img.size)
img.show()
img.save("imag.png")
# Out:
# (1547, 1209)

# %%
#opening an image
import matplotlib
import cv2 
from matplotlib import pyplot as plt
file_image="news.png"
img=cv2.imread(file_image)

cv2.imshow("original image",img)
cv2.waitKey(0)
# Out:
# -1

# %%
def display(im_path):
    dpi = 80
    im_data = plt.imread(im_path)

    height, width  = im_data.shape[:2]
    
    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
display(file_image)

# %%
#new code

import pytesseract
import cv2

# %%
image=cv2.imread("news.png")
base_image=image.copy()

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite("gray.png",gray)
# Out:
# True

# %%
blur=cv2.GaussianBlur(gray,(7,7),0)

# %%
cv2.imwrite("blur.png",blur)
# Out:
# True

# %%
thresh=cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# %%
cv2.imwrite("thresh.png",thresh)
# Out:
# True

# %%
kernel=cv2.getStructuringElement(cv2.MORPH_RECT,(3,13))

# %%
cv2.imwrite("kernel.png",kernel)
# Out:
# True

# %%
dilate=cv2.dilate(thresh,kernel,iterations=1)

# %%
cv2.imwrite("dilate.png",dilate)
# Out:
# True

# %%
#bounding boxes code
cnts= cv2.findContours(dilate,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

# %%
cnts=cnts[0] if len(cnts) == 2 else cents[1]

# %%
cnts=sorted(cnts,key=lambda x: cv2.boundingRect(x[0]))

# %%
for c in cnts:
    x,y,w,h=cv2.boundingRect(c)
    if h>20 and w>10:
        cv2.rectangle(image, (x,y), (x+w, y+h), (36,255,12),2)
cv2.imwrite("box.png",image)
# Out:
# True

# %%
for c in cnts:
    x,y,w,h=cv2.boundingRect(c)
    if h>20 and w>10:
        roi=image[y:y+h,x:x+h]
        cv2.imwrite("roi.png",roi)
        cv2.rectangle(image, (x,y), (x+w, y+h), (36,255,12),2)
cv2.imwrite("box.png",image)
# Out:
# True

# %%
for c in cnts:
    x,y,w,h=cv2.boundingRect(c)
    if h>20 and w>10:
        roi=image[y:y+h,x:x+h]
       # cv2.imwrite("roi.png",roi)
        cv2.rectangle(image, (x,y), (x+w, y+h), (36,255,12),2)
        ocr_result=pytesseract.image_to_string(image)
        ocr_result=ocr_result.split("\n")
        for item in ocr_result:
            item=item.strip()
            print(item)
cv2.imwrite("box.png",image)
# Out:
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
#
#
#
# Wate = veal iF Me.
# ane otl
#
# COUNCIL OF FOREIGN MINISTERS UNDERWAY
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\github\tessaract_ocr_engine\tessaract_OCR_engine\pre-processessing.ipynb Cell 23' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/github/tessaract_ocr_engine/tessaract_OCR_engine/pre-processessing.ipynb#ch0000022?line=4'>5</a> # cv2.imwrite("roi.png",roi)
#       <a href='vscode-notebook-cell:/d%3A/github/tessaract_ocr_engine/tessaract_OCR_engine/pre-processessing.ipynb#ch0000022?line=5'>6</a>  cv2.rectangle(image, (x,y), (x+w, y+h), (36,255,12),2)
# ----> <a href='vscode-notebook-cell:/d%3A/github/tessaract_ocr_engine/tessaract_OCR_engine/pre-processessing.ipynb#ch0000022?line=6'>7</a>  ocr_result=pytesseract.image_to_string(image)
#       <a href='vscode-notebook-cell:/d%3A/github/tessaract_ocr_engine/tessaract_OCR_engine/pre-processessing.ipynb#ch0000022?line=7'>8</a>  ocr_result=ocr_result.split("\n")
#       <a href='vscode-notebook-cell:/d%3A/github/tessaract_ocr_engine/tessaract_OCR_engine/pre-processessing.ipynb#ch0000022?line=8'>9</a>  for item in ocr_result:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pytesseract\pytesseract.py:416, in image_to_string(image, lang, config, nice, output_type, timeout)
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=410'>411</a> """
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=411'>412</a> Returns the result of a Tesseract OCR run on the provided image to string
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=412'>413</a> """
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=413'>414</a> args = [image, 'txt', lang, config, nice, timeout]
# --> <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=415'>416</a> return {
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=416'>417</a>     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=417'>418</a>     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=418'>419</a>     Output.STRING: lambda: run_and_get_output(*args),
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=419'>420</a> }[output_type]()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pytesseract\pytesseract.py:419, in image_to_string.<locals>.<lambda>()
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=410'>411</a> """
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=411'>412</a> Returns the result of a Tesseract OCR run on the provided image to string
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=412'>413</a> """
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=413'>414</a> args = [image, 'txt', lang, config, nice, timeout]
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=415'>416</a> return {
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=416'>417</a>     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=417'>418</a>     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=418'>419</a>     Output.STRING: lambda: run_and_get_output(*args),
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=419'>420</a> }[output_type]()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pytesseract\pytesseract.py:286, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=274'>275</a> with save(image) as (temp_name, input_filename):
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=275'>276</a>     kwargs = {
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=276'>277</a>         'input_filename': input_filename,
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=277'>278</a>         'output_filename_base': temp_name,
#    (...)
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=282'>283</a>         'timeout': timeout,
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=283'>284</a>     }
# --> <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=285'>286</a>     run_tesseract(**kwargs)
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=286'>287</a>     filename = kwargs['output_filename_base'] + extsep + extension
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=287'>288</a>     with open(filename, 'rb') as output_file:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pytesseract\pytesseract.py:260, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=256'>257</a>         raise e
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=257'>258</a>     raise TesseractNotFoundError()
# --> <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=259'>260</a> with timeout_manager(proc, timeout) as error_string:
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=260'>261</a>     if proc.returncode:
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=261'>262</a>         raise TesseractError(proc.returncode, get_errors(error_string))
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/contextlib.py?line=116'>117</a> del self.args, self.kwds, self.func
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/contextlib.py?line=117'>118</a> try:
# --> <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/contextlib.py?line=118'>119</a>     return next(self.gen)
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/contextlib.py?line=119'>120</a> except StopIteration:
#     <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/contextlib.py?line=120'>121</a>     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pytesseract\pytesseract.py:126, in timeout_manager(proc, seconds)
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=123'>124</a> try:
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=124'>125</a>     if not seconds:
# --> <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=125'>126</a>         yield proc.communicate()[1]
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=126'>127</a>         return
#     <a href='file:///c%3A/Users/MrLaptop/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pytesseract/pytesseract.py?line=128'>129</a>     try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\subprocess.py:1134, in Popen.communicate(self, input, timeout)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1130'>1131</a>     endtime = None
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1132'>1133</a> try:
# -> <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1133'>1134</a>     stdout, stderr = self._communicate(input, endtime, timeout)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1134'>1135</a> except KeyboardInterrupt:
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1135'>1136</a>     # https://bugs.python.org/issue25942
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1136'>1137</a>     # See the detailed comment in .wait().
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1137'>1138</a>     if timeout is not None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\subprocess.py:1508, in Popen._communicate(self, input, endtime, orig_timeout)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1503'>1504</a> # Wait for the reader threads, or time out.  If we time out, the
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1504'>1505</a> # threads remain reading and the fds left open in case the user
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1505'>1506</a> # calls communicate again.
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1506'>1507</a> if self.stdout is not None:
# -> <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1507'>1508</a>     self.stdout_thread.join(self._remaining_time(endtime))
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1508'>1509</a>     if self.stdout_thread.is_alive():
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/subprocess.py?line=1509'>1510</a>         raise TimeoutExpired(self.args, orig_timeout)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\threading.py:1053, in Thread.join(self, timeout)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1049'>1050</a>     raise RuntimeError("cannot join current thread")
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1051'>1052</a> if timeout is None:
# -> <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1052'>1053</a>     self._wait_for_tstate_lock()
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1053'>1054</a> else:
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1054'>1055</a>     # the behavior of a negative timeout isn't documented, but
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1055'>1056</a>     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1056'>1057</a>     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\threading.py:1073, in Thread._wait_for_tstate_lock(self, block, timeout)
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1069'>1070</a>     return
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1071'>1072</a> try:
# -> <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1072'>1073</a>     if lock.acquire(block, timeout):
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1073'>1074</a>         lock.release()
#    <a href='file:///c%3A/Program%20Files/WindowsApps/PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0/lib/threading.py?line=1074'>1075</a>         self._stop()
#
# KeyboardInterrupt:
